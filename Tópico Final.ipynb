# %% [markdown]
# # Introdução à Agronomia com Python e dados (MC 5)

# %% [markdown]
# ## Tópico 2.5  Dados online

# %% [markdown]
# https://pypi.org/project/yfinance/
#
# https://finance.yahoo.com/quote/SB=F?p=SB=F&.tsrc=fin-srch
#
# https://analyticsindiamag.com/hands-on-guide-to-using-yfinance-api-in-python/

# %%
#!pip install yahoofinancials
import pandas as pd

import yfinance as yf
from yahoofinancials import YahooFinancials

import time
from os import system, name

import numpy as np
import matplotlib.pyplot as plt

# %%
df = yf.download('SB=F', start='2021-01-22', end='2021-01-23', progress=False, interval="1m")
df.reset_index()
# Out:
#                      Datetime   Open   High    Low  Close  Adj Close  Volume
# 0   2021-01-22 03:30:00-05:00  15.95  15.99  15.93  15.94      15.94       0
# 1   2021-01-22 03:31:00-05:00  15.94  15.95  15.92  15.93      15.93     235
# 2   2021-01-22 03:32:00-05:00  15.93  15.93  15.92  15.92      15.92      13
# 3   2021-01-22 03:33:00-05:00  15.92  15.93  15.87  15.91      15.91     399
# 4   2021-01-22 03:34:00-05:00  15.92  15.92  15.92  15.92      15.92       7
# ..                        ...    ...    ...    ...    ...        ...     ...
# 522 2021-01-22 12:56:00-05:00  15.84  15.84  15.81  15.82      15.82     395
# 523 2021-01-22 12:57:00-05:00  15.81  15.83  15.81  15.83      15.83     104
# 524 2021-01-22 12:58:00-05:00  15.83  15.85  15.82  15.83      15.83     215
# 525 2021-01-22 12:59:00-05:00  15.83  15.86  15.83  15.85      15.85    1238
# 526 2021-01-22 12:59:59-05:00  15.85  15.85  15.85  15.85      15.85       0
#
# [527 rows x 7 columns]

# %%
from IPython.display import clear_output

compra = 15.7
target = 18

contador = 1

for a in range(6):
#while True:
    clear_output(wait=True)
    
    print("Rodada: ",contador,"\n")
    
    print("Compra: ",compra)
    print("Target: ",target)
    
    df = yf.download('SB=F', start='2021-01-22', end='2021-01-23', progress=False, interval="90m")
    print("Dados dos últimos 90 min \n")
    print("Mínimo: ",df["Adj Close"].min())
    print("Máximo: ",df["Adj Close"].max())
    print("Média: ",df["Adj Close"].mean())
    
    df2 = yf.download('SB=F', start='2021-01-22', end='2021-01-23', progress=False, interval="1m")
    df2 = df2.reset_index()
    
    fim = df.tail(1)["Adj Close"][0]
    print("Preço atual: ",fim)
    
    if compra < fim:
        print("\n\nHá lucro de ",fim-compra)
    else:
        print("\n\nHá prejuizo de ",compra-fim)
    
    if fim > target:
        print("Vende! Vende! Vende")
    else:
        print("Não vende...")
    
    print("\n\n Dados dos últimos 5 minutos \n")
    print(df2.tail(5))

    contador = contador + 1
  
    
    time.sleep(1)
# Out:
# Rodada:  6
#
# Compra:  15.7
# Target:  18
# Dados dos últimos 90 min
#
# Mínimo:  15.8100004196167
# Máximo:  15.9399995803833
# Média:  15.87125015258789
# Preço atual:  15.850000381469727
#
#
# Há lucro de  0.15000038146972727
# Não vende...
#
#
#  Dados dos últimos 5 minutos
#
#                      Datetime   Open   High    Low  Close  Adj Close  Volume
# 522 2021-01-22 12:56:00-05:00  15.84  15.84  15.81  15.82      15.82     395
# 523 2021-01-22 12:57:00-05:00  15.81  15.83  15.81  15.83      15.83     104
# 524 2021-01-22 12:58:00-05:00  15.83  15.85  15.82  15.83      15.83     215
# 525 2021-01-22 12:59:00-05:00  15.83  15.86  15.83  15.85      15.85    1238
# 526 2021-01-22 12:59:59-05:00  15.85  15.85  15.85  15.85      15.85       0

# %% [markdown]
# https://stackoverflow.com/questions/39658717/plot-dynamically-changing-graph-using-matplotlib-in-jupyter-notebook

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

m = 100
n = 100
matrix = np.random.normal(0,1,m*n).reshape(m,n)

fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()

for i in range(0,10):
    df2 = yf.download('SB=F', start='2021-01-22', end='2021-01-23', progress=False, interval="1m")
    df2 = df2.tail(5)
    x = df2["Adj Close"]
    ax.clear()
    ax.plot(x)
    fig.canvas.draw()
    time.sleep(10)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-1cd8ed8cfedf> in <module>
#      21     ax.plot(x)
#      22     fig.canvas.draw()
# ---> 23     time.sleep(10)
#
# KeyboardInterrupt:

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

m = 100
n = 100
matrix = np.random.normal(0,1,m*n).reshape(m,n)

fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()

for i in range(0,100):
    ax.clear()
    ax.plot(matrix[i,:])
    fig.canvas.draw()

# %% [markdown]
# ## Revisão

# %% [markdown]
# ## Tópico 1
#     Conceitos de Lógica de Programação
#     Bibliotecas numpy, pandas, matplotlib
#
# ## Tópico 2.1. População mundial e Produção de Alimentos
#     Exploramos a base de população da FAO e constatamos que a produção de alimentos cresceu em taxa superior à população.
#     Também vimos que população urbana não é correlacionada à desenvolvimento humano.
#     Exploramos a função pandas.read_csv()
# ## Tópico 2.2. Uso da terra, Fertilizantes e defensivos. Florestas, Poluição e Emissões de gás carbônico
#     Vimos que as florestas brasileiras reduziram em 10% nos últimos 10 anos, mas não foram convertidas diretamente em lavouras
#     Notamos a forte correlação entre os inputs fertilizante e defensivo, com produção agrícola.
#     Vimos que relativamente (em dados por tonelada, especialmente, ou ha) o uso de inputs no Brasil é pequeno.
#     Exploramos a tabela dinâmica do python
#     Fizemos o arquivo que monta relatório único e que busca trecho de textos.
# ### Módulo 2.3. Comercialização de Commodities
#     Exploramos dados de preço do CEPEA, do QUANDL e fizemos um API de preço usando uma biblioteca..
#     Exploramos a balança comercial com dados do commex.
# ### Módulo 2.4. IBGE
#     Exploramos a base do IBGE e montamos um API do zero
# ### Pendências - EMBRAPA, BNDES, CONVERSA AGRÔNOMO, Tableau.
#     https://apis.bndes.gov.br/store/docs/
#     https://www.agroapi.cnptia.embrapa.br/portal/

# %% [markdown]
# https://machinelearningmastery.com/how-to-develop-lstm-models-for-time-series-forecasting/

# %%
df = yf.download('SB=F', start='2021-01-22', end='2021-01-23', progress=False, interval="1m")
df = df.reset_index()
y = df["Adj Close"]
y
# Out:
# 0      15.94
# 1      15.93
# 2      15.92
# 3      15.91
# 4      15.92
#        ...
# 522    15.82
# 523    15.83
# 524    15.83
# 525    15.85
# 526    15.85
# Name: Adj Close, Length: 527, dtype: float64

# %% [markdown]
# https://machinelearningmastery.com/how-to-develop-lstm-models-for-time-series-forecasting/

# %%
y = np.array(y)

# %%
i = df["Adj Close"].tail(3)
i = np.array(i)

# %%
lista = y
input = i

# %%
# univariate lstm example
from numpy import array
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
 
# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the sequence
		if end_ix > len(sequence)-1:
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)
 
# define input sequence

raw_seq = lista
# choose a number of time steps
n_steps = 3
# split into samples
X, y = split_sequence(raw_seq, n_steps)
# reshape from [samples, timesteps] into [samples, timesteps, features]
n_features = 1
X = X.reshape((X.shape[0], X.shape[1], n_features))
# define model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(n_steps, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# fit model
model.fit(X, y, epochs=200, verbose=0)
# demonstrate prediction
x_input = input
x_input = x_input.reshape((1, n_steps, n_features))
yhat = model.predict(x_input, verbose=0)
print(yhat)
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000222F9140798> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[15.815519]]

# %% [markdown]
# Download: https://www.tableau.com/pt-br/support/releases
#
# Licença estudantes: https://www.tableau.com/pt-br/academic/students
